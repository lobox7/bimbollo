# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('train.csv', nrows=1000000)

# %%
data.describe(include="all")
# Out:
#         Semana      Agencia_ID        Canal_ID        Ruta_SAK  \
# count  1000000  1000000.000000  1000000.000000  1000000.000000
# mean         3     1119.880522        1.066424     1588.443300
# std          0        4.943890        0.590644      833.859215
# min          3     1110.000000        1.000000        1.000000
# 25%          3     1117.000000        1.000000     1096.000000
# 50%          3     1120.000000        1.000000     1423.000000
# 75%          3     1123.000000        1.000000     1603.000000
# max          3     1130.000000       11.000000     4501.000000
#
#             Cliente_ID     Producto_ID   Venta_uni_hoy       Venta_hoy  \
# count   1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean    1344408.648329    13566.496539        6.646702       70.972177
# std     1492811.309201    17223.695381       17.139278      287.996647
# min        3967.000000       72.000000        0.000000        0.000000
# ...

# %%
data.head(1)
# Out:
#    Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0       3        1110         7      3301       15766         1212
#
#    Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  Demanda_uni_equil
# 0              3      25.14                0            0                  3

# %%
data["Ruta_SAK"].hist(bins=20)

# %%
data["Venta_hoy"].hist(bins=50,range=[0, 500])

# %%
data.hist(bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000011EBACE8B38>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000011EBB0DE898>]], dtype=object)

# %%
data["Demanda_uni_equil"].hist(bins=50,range=[0, 50])

# %%
data[["Demanda_uni_equil",'Venta_hoy']]
# Out:
#         Demanda_uni_equil  Venta_hoy
# 0                       3      25.14
# 1                       4      33.52
# 2                       4      39.32
# 3                       4      33.52
# 4                       3      22.92
# 5                       5      38.20
# 6                       3      20.28
# 7                       6      56.10
# 8                       4      24.60
# 9                       6      31.68
# 10                      8      62.24
# 11                      4      21.52
# 12                     12      75.00
# 13                      7      43.75
# 14                     10      62.50
# 15                      5      15.10
# 16                      3      21.12
# 17                      3      21.12
# 18                      8      36.00
# 19                     12      90.00
# 20                      8      60.00
# 21                      4      39.64
# 22                      5      22.90
# 23                     18     172.80
# ...
